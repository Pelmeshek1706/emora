# %% [markdown]
# # OpenWillis Face Demo
#
# Run this notebook with the `Python (airest-voice)` kernel after setup from `README.md`.
#
# This notebook runs the demo call exactly as requested.

# %%
import openwillis.face as ef

framewise_loc, framewise_disp, summary = ef.facial_expressivity(
	filepath = 'video.mov', 
	baseline_filepath = '/Users/pelmeshek1706/Downloads/baseline (1).mp4', 
	bbox_list = [], 
	base_bbox_list = [], 
	frames_per_second = 10, 
	normalize = True, 
	align = False, 
	rolling_std_seconds = 3, 
	split_by_speaking = False)
# Out:
# 644 0
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778767007.081533 19701048 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 89.4), renderer: Apple M3 Pro
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1778767007.093502 19701595 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778767007.097410 19701597 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778767007.110772 19701593 landmark_projection_calculator.cc:186] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# 104 0
# I0000 00:00:1778767021.354277 19701048 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 89.4), renderer: Apple M3 Pro
# W0000 00:00:1778767021.356062 19702269 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778767021.358584 19702269 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %%
framewise_loc
# Out:
#      lmk001_x  lmk002_x  lmk003_x  lmk004_x  lmk005_x  lmk006_x  lmk007_x  \
# 0         0.0  0.006496  0.000089 -0.042407  0.006654  0.004096 -0.004326
# 1         0.0  0.005665  0.001383 -0.041335  0.005709  0.004155 -0.001291
# 2         0.0  0.004379 -0.000209 -0.043567  0.004409  0.002430 -0.004730
# 3         0.0  0.005084  0.000935 -0.041371  0.005344  0.003924 -0.001644
# 4         0.0  0.004640  0.000728 -0.042335  0.004775  0.003231 -0.002636
# ..        ...       ...       ...       ...       ...       ...       ...
# 639       0.0  0.012351  0.009473 -0.017473  0.015791  0.021150  0.034213
# 640       0.0  0.012284  0.009120 -0.017921  0.015748  0.020926  0.033451
# 641       0.0  0.011049  0.008034 -0.019926  0.014365  0.019223  0.030950
# 642       0.0  0.013457  0.009508 -0.017233  0.017020  0.022013  0.033706
# 643       0.0  0.013662  0.009340 -0.018099  0.017055  0.021580  0.031860
#
#      lmk008_x  lmk009_x  lmk010_x  ...  lmk461_z  lmk462_z  lmk463_z  \
# 0   -0.371953 -0.007383 -0.007285  ...  0.055831 -0.073814 -0.016567
# 1   -0.360126 -0.003039 -0.002863  ...  0.054953 -0.075230 -0.017735
# 2   -0.364190 -0.006648 -0.006246  ...  0.056256 -0.071592 -0.015952
# 3   -0.357696 -0.002934 -0.002317  ...  0.054986 -0.071247 -0.016042
# 4   -0.360851 -0.004075 -0.003553  ...  0.054936 -0.071363 -0.016084
# ..        ...       ...       ...  ...       ...       ...       ...
# 639 -0.310951  0.044532  0.049792  ...  0.039764 -0.084065 -0.027390
# 640 -0.313517  0.043645  0.048957  ...  0.040374 -0.083602 -0.027056
# 641 -0.316952  0.040842  0.046148  ...  0.040642 -0.084335 -0.027350
# 642 -0.315006  0.043664  0.049023  ...  0.040702 -0.083825 -0.027253
# 643 -0.317997  0.040708  0.045529  ...  0.041188 -0.084691 -0.027601
#
#      lmk464_z  lmk465_z  lmk466_z  lmk467_z  lmk468_z  frame       time
# 0    0.220041  0.187708  0.152428  0.261870  0.265833      0   0.000000
# 1    0.215802  0.183698  0.147301  0.256126  0.259284      1   0.033333
# 2    0.216092  0.184717  0.149814  0.258217  0.262560      2   0.066667
# 3    0.212429  0.181822  0.147732  0.252106  0.256341      3   0.100000
# 4    0.212549  0.181967  0.147918  0.252575  0.256864      4   0.133333
# ..        ...       ...       ...       ...       ...    ...        ...
# 639  0.174210  0.146188  0.114436  0.204239  0.206783    639  21.300000
# 640  0.176828  0.148527  0.116636  0.208032  0.210854    640  21.333333
# 641  0.176717  0.148108  0.115811  0.208460  0.211194    641  21.366667
# 642  0.179683  0.151054  0.118773  0.212028  0.214851    642  21.400000
# 643  0.181202  0.151924  0.118743  0.214525  0.217037    643  21.433333
#
# [644 rows x 1406 columns]

# %%
framewise_disp
# Out:
#      frame       time    lmk001    lmk002    lmk003    lmk004    lmk005  \
# 0        0   0.000000       NaN       NaN       NaN       NaN       NaN
# 1        1   0.033333 -0.000522  0.023118  0.015908  0.020357  0.023935
# 2        2   0.066667 -0.000522  0.003968  0.001483  0.004244  0.004332
# 3        3   0.100000 -0.000522  0.001123  0.000881  0.003009  0.001461
# 4        4   0.133333 -0.000522  0.000984  0.000632  0.002961  0.001399
# ..     ...        ...       ...       ...       ...       ...       ...
# 639    639  21.300000 -0.000522  0.000944  0.001730  0.002612  0.001095
# 640    640  21.333333 -0.000522  0.001402  0.000128  0.002648  0.002059
# 641    641  21.366667 -0.000522  0.007593  0.004817  0.008263  0.008240
# 642    642  21.400000 -0.000522  0.003851  0.001760  0.002986  0.003979
# 643    643  21.433333 -0.000522  0.007886  0.003479  0.011029  0.009644
#
#        lmk006    lmk007    lmk008  ...    lmk465    lmk466    lmk467  \
# 0         NaN       NaN       NaN  ...       NaN       NaN       NaN
# 1    0.022480  0.018437  0.019423  ...  0.015776  0.016613  0.019185
# 2    0.004474  0.006794  0.013152  ...  0.011360  0.009607  0.025483
# 3    0.002091  0.004422  0.007117  ...  0.005368  0.004902  0.006032
# 4    0.002258  0.004422  0.004476  ...  0.004848  0.004776  0.006958
# ..        ...       ...       ...  ...       ...       ...       ...
# 639  0.001621  0.004262  0.009467  ...  0.007306  0.006236  0.011353
# 640  0.002640  0.002788  0.002289  ...  0.002177  0.002281  0.003492
# 641  0.008398  0.008478  0.005438  ...  0.006189  0.006743  0.005400
# 642  0.003456  0.004136  0.005726  ...  0.006599  0.005596  0.007295
# 643  0.010900  0.012209  0.009318  ...  0.008601  0.009240  0.003389
#
#        lmk468   overall  lower_face  upper_face      lips  eyebrows  \
# 0         NaN       NaN         NaN         NaN       NaN       NaN
# 1    0.018637  0.016821    0.013378    0.018802  0.009009  0.015412
# 2    0.017046  0.008674    0.006135    0.010114  0.001901  0.011854
# 3    0.006881  0.004809    0.002629    0.006048  0.001444  0.011078
# 4    0.007483  0.003456    0.001691    0.004450  0.001239  0.008115
# ..        ...       ...         ...         ...       ...       ...
# 639  0.011247  0.006301    0.005460    0.006773  0.004689  0.007228
# 640  0.003913  0.002968    0.003655    0.002586  0.003148  0.004223
# 641  0.007513  0.005048    0.002225    0.006648  0.001113  0.011789
# 642  0.007729  0.005292    0.004983    0.005477  0.002760  0.005849
# 643  0.005452  0.007815    0.004823    0.009524  0.001910  0.020337
#
#      mouth_openness
# 0          0.137022
# 1          0.185313
# 2          0.185008
# 3          0.195894
# 4          0.179140
# ..              ...
# 639        0.182621
# 640        0.135707
# 641        0.149123
# 642        0.145860
# 643        0.169220
#
# [644 rows x 476 columns]

# %%
summary
# Out:
#    overall_mean  lower_face_mean  upper_face_mean  lips_mean  eyebrows_mean  \
# 0      0.015443         0.014805         0.015817   0.013397        0.02261
#
#    mouth_openness_mean  overall_std  lower_face_std  upper_face_std  lips_std  \
# 0             0.878355       0.0089        0.010404        0.009567  0.011449
#
#    eyebrows_std  mouth_openness_std
# 0       0.01566            0.662627

# %%
print('framewise_loc shape:', framewise_loc.shape)
print('framewise_disp shape:', framewise_disp.shape)
print('summary shape:', summary.shape)
summary.head()
